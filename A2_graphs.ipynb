# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных из файла hybrid_results.csv
data = pd.read_csv("hybrid_results.csv")

# Построение графиков

# 1. Время сортировки от размера массива
plt.figure(figsize=(12, 6))
plt.plot(data['Size'], data['Random'], label='Random Array', color='blue')
plt.plot(data['Size'], data['gen_2'], label='Reverse Array (gen_2)', color='green')
plt.plot(data['Size'], data['gen_3'], label='Nearly Sorted Array (gen_3)', color='orange')

plt.xlabel('Array Size', fontsize=14)
plt.ylabel('Time (μs)', fontsize=14)
plt.title('Sorting Time vs Array Size', fontsize=16)
plt.legend(fontsize=12)
plt.grid()
plt.show()

# 2. Относительное время выполнения (нормализация по Random)
data['Relative_gen_2'] = data['gen_2'] / data['Random'] * 100
data['Relative_gen_3'] = data['gen_3'] / data['Random'] * 100

plt.figure(figsize=(12, 6))
plt.plot(data['Size'], data['Relative_gen_2'], label='Relative Time: Reverse (gen_2)', color='green')
plt.plot(data['Size'], data['Relative_gen_3'], label='Relative Time: Nearly Sorted (gen_3)', color='orange')

plt.axhline(y=100, color='blue', linestyle='--', label='Baseline: Random Array')
plt.xlabel('Array Size', fontsize=14)
plt.ylabel('Relative Time (%)', fontsize=14)
plt.title('Relative Sorting Time vs Array Size', fontsize=16)
plt.legend(fontsize=12)
plt.grid()
plt.show()
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных из файла hybrid_results.csv
data = pd.read_csv("hybrid_results.csv")

# Построение графиков

# 1. Время сортировки от размера массива
plt.figure(figsize=(12, 6))
plt.plot(data['Size'], data['Random'], label='Random Array', color='blue')
plt.plot(data['Size'], data['gen_2'], label='Reverse Array (gen_2)', color='green')
plt.plot(data['Size'], data['gen_3'], label='Nearly Sorted Array (gen_3)', color='orange')

plt.xlabel('Array Size', fontsize=14)
plt.ylabel('Time (μs)', fontsize=14)
plt.title('Sorting Time vs Array Size', fontsize=16)
plt.legend(fontsize=12)
plt.grid()
plt.show()

# 2. Относительное время выполнения (нормализация по Random)
data['Relative_gen_2'] = data['gen_2'] / data['Random'] * 100
data['Relative_gen_3'] = data['gen_3'] / data['Random'] * 100

plt.figure(figsize=(12, 6))
plt.plot(data['Size'], data['Relative_gen_2'], label='Relative Time: Reverse (gen_2)', color='green')
plt.plot(data['Size'], data['Relative_gen_3'], label='Relative Time: Nearly Sorted (gen_3)', color='orange')

plt.axhline(y=100, color='blue', linestyle='--', label='Baseline: Random Array')
plt.xlabel('Array Size', fontsize=14)
plt.ylabel('Relative Time (%)', fontsize=14)
plt.title('Relative Sorting Time vs Array Size', fontsize=16)
plt.legend(fontsize=12)
plt.grid()
plt.show()
